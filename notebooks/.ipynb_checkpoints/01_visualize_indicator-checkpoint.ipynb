# %%
from __future__ import annotations

import pandas as pd
import plotly.graph_objects as go

from data import DataManager
from utils import compute_sr_boxes

# ------------------------------------------------------------------
# Load 15m OHLCV for the past 30 days from OKX
# ------------------------------------------------------------------
manager = DataManager()
end_time = pd.Timestamp.utcnow().floor("min")
start_time = end_time - pd.Timedelta(days=30)

ohlcv_15m = manager.get_klines(
    symbol="BTCUSDT",
    timeframe="15m",
    start=start_time,
    end=end_time,
    source="okx",
)

# ------------------------------------------------------------------
# Compute 4H support/resistance boxes based on the 15m data
# ------------------------------------------------------------------
boxes_df, events_df = compute_sr_boxes(
    data=ohlcv_15m,
    target_timeframe="4h",
    lookback=20,
    volume_length=2,
    box_width_factor=1.0,
)

if not boxes_df.empty:
    boxes_df = boxes_df.sort_values("start").reset_index(drop=True)
if not events_df.empty:
    events_df = events_df.sort_values("time").reset_index(drop=True)
    events_df["time"] = pd.to_datetime(events_df["time"], utc=True)

print(f"Detected {len(boxes_df)} boxes and {len(events_df)} events")

# ------------------------------------------------------------------
# Build interactive visualization with Plotly
# ------------------------------------------------------------------
fig = go.Figure(
    data=[
        go.Candlestick(
            x=ohlcv_15m.index,
            open=ohlcv_15m["open"],
            high=ohlcv_15m["high"],
            low=ohlcv_15m["low"],
            close=ohlcv_15m["close"],
            name="BTCUSDT 15m",
        )
    ]
)

status_colors = {
    ("support", "active"): ("rgba(46, 204, 113, 0.2)", "rgba(39, 174, 96, 1)"),
    ("support", "hold"): ("rgba(46, 204, 113, 0.35)", "rgba(39, 174, 96, 1)"),
    ("support", "broken"): ("rgba(231, 76, 60, 0.25)", "rgba(192, 57, 43, 1)"),
    ("resistance", "active"): ("rgba(231, 76, 60, 0.2)", "rgba(192, 57, 43, 1)"),
    ("resistance", "hold"): ("rgba(231, 76, 60, 0.35)", "rgba(192, 57, 43, 1)"),
    ("resistance", "broken"): ("rgba(46, 204, 113, 0.25)", "rgba(39, 174, 96, 1)"),
}

for _, box in boxes_df.iterrows():
    fill, line = status_colors.get((box["type"], box["status"]), ("rgba(189, 195, 199, 0.18)", "rgba(127, 140, 141, 1)"))
    fig.add_shape(
        type="rect",
        xref="x",
        yref="y",
        x0=box["start"],
        x1=box["end"],
        y0=box["lower"],
        y1=box["upper"],
        fillcolor=fill,
        line=dict(color=line, width=1, dash="dash" if box["status"] == "broken" else "solid"),
        layer="below",
    )

if not events_df.empty:
    hover_text = events_df["type"].str.replace("_", " ")
    fig.add_trace(
        go.Scatter(
            x=events_df["time"],
            y=events_df["price"],
            mode="markers",
            marker=dict(
                size=8,
                color=events_df["type"].map(
                    {
                        "support_break": "rgba(192, 57, 43, 0.9)",
                        "support_hold": "rgba(39, 174, 96, 0.9)",
                        "resistance_break": "rgba(39, 174, 96, 0.9)",
                        "resistance_hold": "rgba(192, 57, 43, 0.9)",
                    }
                ).fillna("rgba(127, 140, 141, 0.9)"),
            ),
            name="Events",
            text=hover_text,
            hovertemplate="%{text}<br>%{x|%Y-%m-%d %H:%M} @ %{y:.2f}<extra></extra>",
        )
    )

fig.update_layout(
    title="BTCUSDT 15m with 4H Support/Resistance Boxes",
    xaxis_title="Time",
    yaxis_title="Price",
    template="plotly_white",
    height=720,
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File D:\Projects\PythonProjects\taoquant\data\sources\okx_sdk.py:29, in OkxSDKDataSource.__init__(self, flag, inst_type, max_batch, max_total, sleep_seconds)
#      28 try:
# ---> 29     from okx.api import Market  # type: ignore
#      30 except ImportError as exc:  # pragma: no cover
#
# ModuleNotFoundError: No module named 'okx.api'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 16
#      13 end_time = pd.Timestamp.utcnow().floor("min")
#      14 start_time = end_time - pd.Timedelta(days=30)
# ---> 16 ohlcv_15m = manager.get_klines(
#      17     symbol="BTCUSDT",
#      18     timeframe="15m",
#      19     start=start_time,
#      20     end=end_time,
#      21     source="okx",
#      22 )
#      24 # ------------------------------------------------------------------
#      25 # Compute 4H support/resistance boxes based on the 15m data
#      26 # ------------------------------------------------------------------
#      27 boxes_df, events_df = compute_sr_boxes(
#      28     data=ohlcv_15m,
#      29     target_timeframe="4h",
#    (...)
#      32     box_width_factor=1.0,
#      33 )
#
# File D:\Projects\PythonProjects\taoquant\data\data_manager.py:53, in DataManager.get_klines(self, symbol, timeframe, start, end, source, use_cache)
#      50         return cached_df
#      52 if source in self.EXTERNAL_SOURCE_MAP:
# ---> 53     handler = self._load_external_source(source)
#      54     data = handler.get_klines(symbol, timeframe, start=start, end=end)
#      55 elif source == "csv":
#
# File D:\Projects\PythonProjects\taoquant\data\data_manager.py:317, in DataManager._load_external_source(self, name)
#     315 except ImportError as exc:  # pragma: no cover
#     316     raise ImportError(f"Failed to import data source '{name}'. Ensure required package is installed.") from exc
# --> 317 instance = cls()
#     318 if not isinstance(instance, MarketDataSource):
#     319     raise TypeError(f"Data source '{name}' must inherit from MarketDataSource.")
#
# File D:\Projects\PythonProjects\taoquant\data\sources\okx_sdk.py:31, in OkxSDKDataSource.__init__(self, flag, inst_type, max_batch, max_total, sleep_seconds)
#      29     from okx.api import Market  # type: ignore
#      30 except ImportError as exc:  # pragma: no cover
# ---> 31     raise ImportError("okx package is required for OkxSDKDataSource. Install via pip install okx.") from exc
#      33 self._market_api = Market(flag=flag)
#      34 self._inst_type = inst_type.upper()
#
# ImportError: okx package is required for OkxSDKDataSource. Install via pip install okx.
